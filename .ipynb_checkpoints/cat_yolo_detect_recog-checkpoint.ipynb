# %% [markdown]
# # Yolo_Detect/Recog

# %%
#import libs
from src import *

# %%
im = cv2.imread("test_images/cat.jpg")
yolob = Yolobody()
yoloe = Yoloeye()
yolof = Yoloface()
haar = HaarCascadeExt()
face_database = Model()
# Out:
# Alright, you didn't input a model so we will start from scratch

# %%
ret = yolob.detect(im)
x,y,w,h = ret[0][2]
X,Y,W,H = cent2rect(x,y,w,h)
plt.imshow(add_rect(im,(X,Y,W,H)))

# %%
ret = yoloe.detect(im)
x,y,w,h = ret[0][2]
X,Y,W,H = cent2rect(x,y,w,h)
plt.imshow(add_rect(im,(X,Y,W,H)))

# %%
ret = yolof.detect(im)
x,y,w,h = ret[0][2]
X,Y,W,H = cent2rect(x,y,w,h)
plt.imshow(add_rect(im,(X,Y,W,H)))

# %%
croped = im[Y:Y+H,X:X+W]
nX,nY,nW,nH = haar.detect(croped,(0,0))[0]
plt.imshow(add_rect(croped,(nX,nY,nW,nH)))

# %%
closeup = croped[nY:nY+nH,nX:nX+nW]
plt.imshow(closeup)

# %%
face_database.training([closeup],0)
# Out:
# Gathering Data to train on !
# Model updated sucessefully, Congratulations

# %%
face_database.prediction(closeup)
# Out:
# (0, 0.0)
